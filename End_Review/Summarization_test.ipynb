# %%
# !pip install transformers
# !pip install PyPDF2
! pip install spellchecker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 47.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 25.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install gensim==3.8.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 60.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for gensim: filename=gensim-3.8.3-cp39-cp39-linux_x86_64.whl size=26528011 sha256=1b5c74fc7a7ccb44e5c727f44d7f24143d4f361c8357ddc13569a716ea26a861
#   Stored in directory: /root/.cache/pip/wheels/ca/5d/af/618594ec2f28608c1d6ee7d2b7e95a3e9b06551e3b80a491d6
# Successfully built gensim
# ...
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.1
#     Uninstalling gensim-4.3.1:
#       Successfully uninstalled gensim-4.3.1
# ...

# %%
from transformers import pipeline 
import os
from PyPDF2 import PdfReader
import re
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import warnings
import requests
import tweepy

warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split 
# from sklearn.preprocessing import  MinMaxScaler 
from sklearn.preprocessing import  StandardScaler 
from sklearn import metrics as mt
# from spellchecker import SpellChecker 
import nltk
nltk.download('punkt')
from nltk import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
from sklearn.model_selection import GridSearchCV
import re
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.datasets import make_classification

import os
import re
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pdf_path = '/content/drive/MyDrive/sampled_data_for_bda/'

# %%
os.chdir(pdf_path)

# %%
import shutil

shutil.rmtree('/content/download_data/', ignore_errors=True)

os.mkdir("/content/download_data/")

# %%
def download_pdf_file(url: str) -> bool:

  """Download PDF from given URL to local directory.

  :param url: The url of the PDF file to be downloaded

  :return: True if PDF file was successfully downloaded, otherwise False.

  """

  # Request URL and get response object

  response = requests.get(url, stream=True)

  # isolate PDF filename from URL

  pdf_file_name = os.path.basename(url)

  if response.status_code == 200:

    # Save in current working directory

    

    filepath = os.path.join("/content/download_data", pdf_file_name)

    with open(filepath, 'wb') as pdf_object:

      pdf_object.write(response.content)

      print(f'{pdf_file_name} was successfully saved!')

      return True

  else:

    print(f'Uh oh! Could not download {pdf_file_name},')

    print(f'HTTP response status code: {response.status_code}')

    return False

if __name__ == '__main__':

  # URL from which pdfs to be downloaded

  URL = 'https://arxiv.org/pdf/0704.2902.pdf'

  download_pdf_file(URL)
# Out:
# 0704.2902.pdf was successfully saved!

# %%
# id = "0704.0213.pdf"

# %%
# file = "/content/download_data/"

# %%
final = []
files = os.listdir('/content/download_data/')
c=0
for file in files:
  lst = []
  print(file)
  if c<2:
    pdf_reader = PdfReader(file)
    
    # Get the total number of pages in the PDF file
    num_pages = len(pdf_reader.pages)
    
    # Create an empty string to store the content of the PDF file
    content = ""
    
    # Loop through each page in the PDF file and extract its text
    for page in range(num_pages):
        pdf_page = pdf_reader.pages[page]
        text = pdf_page.extract_text()
        content += text
    lst.append(content)
    final.append(lst)
  else:
    break
  c+=1
    # Print the extracted content of the PDF file
    #print(content)
# Out:
# 0704.2902.pdf

# %%
final_df = pd.DataFrame(final,columns=["text"])
final_df
# Out:
#                                                 text
# 0  Recommending Related Papers\nBased on Digital ...

# %%
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

import en_core_web_sm

# %%
content = final_df["text"]
nlp = en_core_web_sm.load()
# = nlp(content)
#doc = content.apply(nlp)



summ_per = content.apply(summarize,ratio = 0.5)

summ_words = content.apply(summarize, word_count = 1000)

final_df['summ_per'] = summ_per
final_df['summ_words'] = summ_words

# %%
len(str(summ_per))
# Out:
# 80

# %%
summarizer = pipeline("summarization", model="t5-base", tokenizer="t5-base", framework="tf")
# ptorch1 = summarizer(final_df['summ_words'], min_length=500)
# ptorch1 = final_df['summ_words'].apply(summarizer,min_length=500,max_length = 800)
# print(ptorch1)
# Out:
# ...
# All model checkpoint layers were used when initializing TFT5ForConditionalGeneration.
#
# All the layers of TFT5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# ...

# %%
s = str(summ_per)

# %%
s= '''I apologize, but generating a paragraph of  words without using any special characters or digits would be very difficult as it would require me to string together a large number of words without any spaces, punctuation, or other formatting. Such a paragraph would be extremely difficult to read and would not serve any practical purpose.
However, I can generate a paragraph of  words using only alphabetic characters, with spaces and punctuation included. Here's an example:
In the early morning light, the birds chirped their merry tunes, heralding the start of a new day. The sun slowly rose over the horizon, casting its warm glow across the landscape. As I walked through the fields, I could feel the cool grass beneath my feet and the gentle breeze on my face. It was a peaceful moment, a time to reflect and appreciate the beauty of nature.
As the day wore on, the hustle and bustle of life began to pick up. Cars honked, people rushed to and fro, and the world seemed to spin faster and faster. But even in the chaos, there were moments of stillness, moments when the world slowed down and allowed us to catch our breath.
As the sun began to set, the sky turned a beautiful shade of pink and orange. The clouds danced across the sky, casting their shadows on the world below. It was a breathtaking sight, a reminder of the beauty that surrounds us every day.
As I headed home, I felt grateful for the moments of peace and stillness that I had experienced throughout the day. They reminded me that even in the midst of chaos, there is always a moment of calm waiting for us. And so, I went to bed that night with a heart full of gratitude and a sense of peace that I knew would carry me through the days to come.
I apologize, but generating a paragraph of  words without using any special characters or digits would be very difficult as it would require me to string together a large number of words without any spaces, punctuation, or other formatting. Such a paragraph would be extremely difficult to read and would not serve any practical purpose.
However, I can generate a paragraph of  words using only alphabetic characters, with spaces and punctuation included. Here's an example:
In the early morning light, the birds chirped their merry tunes, heralding the start of a new day. The sun slowly rose over the horizon, casting its warm glow across the landscape. As I walked through the fields, I could feel the cool grass beneath my feet and the gentle breeze on my face. It was a peaceful moment, a time to reflect and appreciate the beauty of nature.
As the day wore on, the hustle and bustle of life began to pick up. Cars honked, people rushed to and fro, and the world seemed to spin faster and faster. But even in the chaos, there were moments of stillness, moments when the world slowed down and allowed us to catch our breath.
As the sun began to set, the sky turned a beautiful shade of pink and orange. The clouds danced across the sky, casting their shadows on the world below. It was a breathtaking sight, a reminder of the beauty that surrounds us every day.
As I headed home, I felt grateful for the moments of peace and stillness that I had experienced throughout the day. They reminded me that even in the midst of chaos, there is always a moment of calm waiting for us. And so, I went to bed that night with a heart full of gratitude and a sense of peace that I knew would carry me through the days to come.
I apologize, but generating a paragraph of  words without using any special characters or digits would be very difficult as it would require me to string together a large number of words without any spaces, punctuation, or other formatting. Such a paragraph would be extremely difficult to read and would not serve any practical purpose.
However, I can generate a paragraph of  words using only alphabetic characters, with spaces and punctuation included. Here's an example:
In the early morning light, the birds chirped their merry tunes, heralding the start of a new day. The sun slowly rose over the horizon, casting its warm glow across the landscape. As I walked through the fields, I could feel the cool grass beneath my feet and the gentle breeze on my face. It was a peaceful moment, a time to reflect and appreciate the beauty of nature.
As the day wore on, the hustle and bustle of life began to pick up. Cars honked, people rushed to and fro, and the world seemed to spin faster and faster. But even in the chaos, there were moments of stillness, moments when the world slowed down and allowed us to catch our breath.
As the sun began to set, the sky turned a beautiful shade of pink and orange. '''
'''

# %%
summarizer = pipeline("summarization", model="t5-base", tokenizer="t5-base", framework="tf")
ptorch1 = summarizer(s, min_length=500,max_length=700)

# print(ptorch1)

# %%
ptorch1[0]

# %%
summarizer = pipeline("summarization") 
ptorch = summarizer(s, min_length=500)

print(ptorch)
